# %% [markdown]
# <b>#Day 1

# %% [markdown]
# <h2><i>Linear Regression

# %%
import numpy as np
import pandas as pd

# %%
#Reading Dataset
train = pd.read_csv(r'F:\W1\_stn_\workspace.py\Machine-Learning-Models\Datasets\housing price\train.csv')
test = pd.read_csv(r'F:\W1\_stn_\workspace.py\Machine-Learning-Models\Datasets\housing price\test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# <b>#Day 2

# %%
import matplotlib.pyplot as plt # Visualization
import seaborn as sns # For easier statistical plotting
sns.set_style("whitegrid")

# %%
pd.set_option('precision',2)
plt.figure(figsize=(15,12))
sns.heatmap(train.drop(["SalePrice","Id"],axis=1).corr(), square=True)
plt.suptitle("Pearson Correlation Heatmap")
plt.show()

# %%
skews = train.skew()
for col in train.drop(["Id","SalePrice"], axis=1).columns.tolist():
    if (train[col].dtype == 'float64') or (train[col].dtype == 'int64') :
        sns.distplot(train[col].dropna(), kde=False, label="skew = " + str(round(skews[col],2)) )
        plt.legend()
        plt.show()
        
del skews
# Out:
# D:\Programs\Anaconda2\envs\tensorflow-gpu\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
corr_with_SalePrice = train.drop(["Id"], axis=1).corr()["SalePrice"].sort_values(ascending=False)
plt.figure(figsize=(14,7))
corr_with_SalePrice.drop("SalePrice").plot.bar()
plt.show()

del corr_with_SalePrice

# %%
plt.figure(figsize=(12,10))
interesting_cols = ["OverallCond", "GrLivArea", "GarageCars", "FullBath", "1stFlrSF", "2ndFlrSF"]
sns.pairplot(train[interesting_cols], dropna=True)
plt.show()

del interesting_cols

# %%
sns.pairplot(train[["OverallCond", "GrLivArea","SalePrice"]])
plt.show()

# %%
for col in train.columns.tolist():
    if train[col].dtype == 'object':
        sns.countplot(col, data=train)
        plt.xticks(rotation=55)
        plt.show()
